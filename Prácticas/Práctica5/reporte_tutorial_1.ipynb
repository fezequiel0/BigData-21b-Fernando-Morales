# %% [markdown]
# ## Your First Deep Learning Project in Python with Keras Step-By-Step
#
# ### Load Data

# %%
# !pip install keras
# !pip install tensorflow
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ...
#   Using cached tensorflow-2.6.0-cp38-cp38-win_amd64.whl (423.2 MB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached clang-5.0-py3-none-any.whl
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached grpcio-1.41.1-cp38-cp38-win_amd64.whl (3.2 MB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# ...
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# ...
#   Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# ### Define Keras Model

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Compile Keras Model

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Fit Keras Model

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 395us/step - loss: 2.8638 - accuracy: 0.6354
# Epoch 2/150
# 77/77 [==============================] - 0s 382us/step - loss: 1.2599 - accuracy: 0.6458
# Epoch 3/150
# 77/77 [==============================] - 0s 382us/step - loss: 1.0931 - accuracy: 0.6484
# Epoch 4/150
# 77/77 [==============================] - 0s 382us/step - loss: 1.0005 - accuracy: 0.6471
# Epoch 5/150
# 77/77 [==============================] - 0s 382us/step - loss: 0.9399 - accuracy: 0.6589
# Epoch 6/150
# 77/77 [==============================] - 0s 934us/step - loss: 0.9349 - accuracy: 0.6615
# Epoch 7/150
# 77/77 [==============================] - 0s 388us/step - loss: 0.8813 - accuracy: 0.6719
# Epoch 8/150
# 77/77 [==============================] - 0s 454us/step - loss: 0.8481 - accuracy: 0.6497
# Epoch 9/150
# 77/77 [==============================] - 0s 441us/step - loss: 0.8447 - accuracy: 0.6680
# Epoch 10/150
# ...

# %% [markdown]
# ### Evaluate Keras Model

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 391us/step - loss: 0.5343 - accuracy: 0.7578
# Accuracy: 75.78

# %% [markdown]
# ### Make Predictions

# %%
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %% [markdown]
# ### Comentarios/claridad del tema
#
# Todo queda bastante claro; a pesar de esto, sería bastante provechoso poder experimentar con los diferentes parámetros que tienen las funciones. Como por ejemplo, a la hora de compilar el modelo, poder saber las diferentes optimizaciones que se pueden hacer o los diferentes valores que puede tener el parámetro `loss`.
#
# ### Reporte
#
# En esta práctica, pudimos obserar todos los pasos para crear un modelo de *machine learning* usando Keras. Los pasos son bastante similares a los diferentes modelos que hemos utilizado con otras librerías, aunque personalmente siento que esta librería permite tener un mayor acceso a personalizar los modelos de una forma mucho más sencilla. POr ende, vimos los pasos de la preparación de datos, la definición del modelo y sus capas, la compilación del modelo, el ajuste del modelo, la evaluación del modelo y finalmente realizamos ciertas predicciones.
#
# Recuerdo haber utilizado `keras` en el curso de `Inteligencia Artificial`, aunque fue más superficial. Por suerte, ahora que ya conozco un poco más del tema en sí, me queda mucho más claro el uso de esta librería. No me quedaron dudas, sino más bien tendría que ponerme a explorar más las capabilidades de estos modelos.
